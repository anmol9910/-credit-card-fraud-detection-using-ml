# %% [markdown]
# <a href="https://colab.research.google.com/github/anmol9910/disney/blob/main/Credit_card_fraud_detection_using_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49610 entries, 0 to 49609
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    49610 non-null  int64
#  1   V1      49610 non-null  float64
#  2   V2      49610 non-null  float64
#  3   V3      49610 non-null  float64
#  4   V4      49609 non-null  float64
#  5   V5      49609 non-null  float64
#  6   V6      49609 non-null  float64
#  7   V7      49609 non-null  float64
#  8   V8      49609 non-null  float64
#  9   V9      49609 non-null  float64
#  10  V10     49609 non-null  float64
#  11  V11     49609 non-null  float64
#  12  V12     49609 non-null  float64
#  13  V13     49609 non-null  float64
#  14  V14     49609 non-null  float64
#  15  V15     49609 non-null  float64
#  16  V16     49609 non-null  float64
#  17  V17     49609 non-null  float64
#  18  V18     49609 non-null  float64
#  19  V19     49609 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    49461
# 1.0      148
# Name: count, dtype: int64

# %% [markdown]
# this dataet is highly unbalance
#  0 -->normal transaction
#  1 -->fraudlent transaction

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (49461, 31)
# (148, 31)

# %%
legit.Amount.describe()
# Out:
# count    49461.000000
# mean        93.099593
# std        253.325102
# min          0.000000
# 25%          7.680000
# 50%         25.000000
# 75%         85.000000
# max      12910.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     148.000000
# mean      100.170676
# std       233.347471
# min         0.000000
# 25%         1.000000
# 50%         9.560000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    28809.010473 -0.220239 -0.003947   0.726173  0.167967 -0.240785
# 1.0    26877.182432 -7.675017  5.448919 -10.398242  5.939649 -5.681176
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.111250 -0.096470  0.042413  0.134593  ...  0.046113 -0.031134
# 1.0   -2.280722 -8.068966  3.739332 -3.587074  ...  0.470319  0.886835
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106800 -0.039391  0.008275  0.135623  0.020410  0.003001  0.004455
# 1.0   -0.225326 -0.284732 -0.084733  0.246743  0.155479  0.603171  0.030658
#
#            Amount
# Class
# 0.0     93.099593
# 1.0    100.170676
#
# [2 rows x 30 columns]

# %% [markdown]
# bulid a dataet contaning both type of transaction
# no. of fraud transaction = 148

# %%
legit_sample = legit.sample(n=148)

# %% [markdown]
# concatenating two dataframes

# %%
new_dataset = pd.concat([legit_sample,fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 8798   11999 -1.714400 -1.138836  3.109419  4.002863 -2.254969  2.098693
# 16939  28307  1.306520 -0.548074  0.338542 -0.616739 -1.016024 -0.969227
# 40042  40069  1.311258  0.075028 -1.292832 -0.483154  2.139257  3.181564
# 9646   14447  1.162074 -0.149109  0.848216  0.165142 -0.650237 -0.055095
# 8829   12062  1.231944 -0.117133  0.551114  0.206507 -0.472340 -0.197685
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 8798   0.754346  0.348696  1.373612  ...  0.323741  0.591839  0.991700
# 16939 -0.405517 -0.080456 -0.783869  ... -0.242747 -0.952329  0.278226
# 40042 -0.505045  0.804860 -0.074071  ... -0.342676 -1.148504  0.095279
# 9646  -0.669793  0.126643  1.586816  ...  0.003371  0.234119  0.011609
# 8829  -0.376843 -0.059448  1.796381  ... -0.229381 -0.204078 -0.109543
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
 new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 46909  42985 -4.075975  0.963031 -5.076070  4.955963 -0.161437 -2.832663
# 46918  42988 -4.423508  1.648048 -6.934388  4.894601 -5.078131  0.010849
# 46998  43028 -1.109646  0.811069 -1.138135  0.935265 -2.330248 -0.116106
# 47802  43369 -3.365319  2.426503 -3.752227  0.276017 -2.305870 -1.961578
# 48094  43494 -1.278138  0.716242 -1.143279  0.217805 -1.293890 -1.168952
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 46909 -7.619765  1.618895 -2.992092  ...  1.030738  0.165328 -1.017502
# 46918 -3.409096  1.409291 -3.260672  ...  0.698359  0.487478  1.228698
# 46998 -1.621986  0.458028 -0.912189  ...  0.641594  0.841755  0.176728
# 47802 -3.029283 -1.674462  0.183961  ...  2.070008 -0.512626 -0.248502
# 48094 -2.564182  0.204532 -1.611155  ...  0.490183  0.470427 -0.126261
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    148
# 1.0    148
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    28266.851351 -0.067265  0.102888   0.792464  0.181937 -0.091953
# 1.0    26877.182432 -7.675017  5.448919 -10.398242  5.939649 -5.681176
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.167661  0.086487 -0.029948  0.243706  ...  0.096467  0.005791
# 1.0   -2.280722 -8.068966  3.739332 -3.587074  ...  0.470319  0.886835
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.091192 -0.005473  0.067906  0.162431  0.074422 -0.040003 -0.011285
# 1.0   -0.225326 -0.284732 -0.084733  0.246743  0.155479  0.603171  0.030658
#
#            Amount
# Class
# 0.0     80.654730
# 1.0    100.170676
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class',axis=1)
Y = new_dataset['Class']

# %% [markdown]
# splitting the data into feature & targets

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 8798   11999 -1.714400 -1.138836  3.109419  4.002863 -2.254969  2.098693
# 16939  28307  1.306520 -0.548074  0.338542 -0.616739 -1.016024 -0.969227
# 40042  40069  1.311258  0.075028 -1.292832 -0.483154  2.139257  3.181564
# 9646   14447  1.162074 -0.149109  0.848216  0.165142 -0.650237 -0.055095
# 8829   12062  1.231944 -0.117133  0.551114  0.206507 -0.472340 -0.197685
# ...      ...       ...       ...       ...       ...       ...       ...
# 46909  42985 -4.075975  0.963031 -5.076070  4.955963 -0.161437 -2.832663
# 46918  42988 -4.423508  1.648048 -6.934388  4.894601 -5.078131  0.010849
# 46998  43028 -1.109646  0.811069 -1.138135  0.935265 -2.330248 -0.116106
# 47802  43369 -3.365319  2.426503 -3.752227  0.276017 -2.305870 -1.961578
# 48094  43494 -1.278138  0.716242 -1.143279  0.217805 -1.293890 -1.168952
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 8798     0.0
# 16939    0.0
# 40042    0.0
# 9646     0.0
# 8829     0.0
#         ...
# 46909    1.0
# 46918    1.0
# 46998    1.0
# 47802    1.0
# 48094    1.0
# Name: Class, Length: 296, dtype: float64

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, stratify = Y, random_state=2)

# %% [markdown]
# split the data into training data and testing data

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (296, 30) (236, 30) (60, 30)

# %%
model = LogisticRegression()

# %% [markdown]
# logistic regression (model training)

# %%
# training the logistic regression model with training data
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %% [markdown]
# model evaluation or accuracy score

# %%
print('Acuuracy on Training data: ',training_data_accuracy)
# Out:
# Acuuracy on Training data:  0.961864406779661

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data :', test_data_accuracy)
# Out:
# Accuracy score on Test Data : 0.9666666666666667
